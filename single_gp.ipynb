# %%
import math
import torch
import gpytorch
import tqdm
from matplotlib import pyplot as plt

import pandas as pd
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from scipy import stats
from time import time
import os


# %matplotlib inline
# %load_ext autoreload
# %autoreload

# %%
def return_data(fold,month,with_scaling, station_id = None):
    train_input = pd.read_csv('AAAI22/data/processed'+'/fold_'+str(fold)+'_train_'+month+'.csv.gz')
    test_input = pd.read_csv('AAAI22/data/processed'+'/fold_'+str(fold)+'_test_'+month+'.csv.gz')
    if station_id != None:
        test_input = test_input[test_input['station_id'] == station_id]
    test_output = np.concatenate((np.array(test_input['PM25_Concentration']).reshape(-1,1), np.array(test_input['CO_Concentration']).reshape(-1,1)), axis=1)
    train_output = np.concatenate((np.array(train_input['PM25_Concentration']).reshape(-1,1), np.array(train_input['CO_Concentration']).reshape(-1,1)), axis=1)
    train_input= train_input.drop(['station_id','PM25_Concentration','CO_Concentration','time','filled'],axis=1)
    try:
        test_input= test_input.drop(['PM25_Concentration','CO_Concentration','station_id','time','filled'],axis=1)
    except:
        test_input= test_input.drop(['station_id','time','filled'],axis=1)
    if with_scaling:
        scaler_x = MinMaxScaler()
        scaler_y = StandardScaler()
        scaler_y1 = StandardScaler()
        # scaler = MinMaxScaler().fit(train_input)
        # train_input = pd.DataFrame(scaler_x.fit_transform(train_input),columns=list(train_input.columns))
        # train_output = scaler_y.fit_transform(train_output)
        # test_input = pd.DataFrame(scaler_x.transform(test_input),columns=list(test_input.columns))
        # scaler = MinMaxScaler().fit(train_input)
        train_input = torch.tensor(scaler_x.fit_transform(train_input)).to(torch.float32)
        test_input = torch.tensor(scaler_x.transform(test_input)).to(torch.float32)
        train_output[:,0] = torch.tensor(scaler_y.fit_transform(train_output[:,0].reshape(-1,1)).reshape(-1,)).to(torch.float32)
        # print(train_output.shape)
        train_output[:,1] = torch.tensor(scaler_y1.fit_transform(train_output[:,1].reshape(-1,1)).reshape(-1,)).to(torch.float32)
        # print(train_output.shape)
        test_output = torch.tensor(test_output[:,0]).to(torch.float32)
    return train_input, torch.tensor(train_output[:,0]).reshape(-1,).to(torch.float32),test_input,test_output, scaler_y, scaler_y1

# %%
for fold in [0]:
    train_input,train_output,test_input,test_output,scaler_pm, scaler_co = return_data(fold=fold,month='mar',with_scaling=True)
    print("Fold: ",fold)
    print("Data received")
# Out:
# Fold:  0
# Data received

# %%
train_input.shape,train_output.shape,test_input.shape,test_output.shape, train_input.type(), train_output.type()
# Out:
# (torch.Size([166440, 5]),
#  torch.Size([166440]),
#  torch.Size([87600, 5]),
#  torch.Size([87600]),
#  'torch.FloatTensor',
#  'torch.FloatTensor')

# %%
train_x, train_y = train_input, train_output

# %%
from skgpytorch.models import SVGPRegressor, SGPRegressor, ExactGPRegressor

# %%
from gpytorch.kernels import (
    RBFKernel,
    ScaleKernel,
    PeriodicKernel,
    MaternKernel,
    CosineKernel,
)

# %%
def GP_model(train, test):
    train_points = 20000
    kernel = ScaleKernel(RBFKernel(ard_num_dims=train_input.shape[1]))
    inducing_points = train_input[np.arange(0, train_points, 1000)]
    model = SGPRegressor(
        train_input[:train_points,:].to("cuda"), train_output[:train_points].to("cuda"), kernel, inducing_points
    ).to("cuda")

    # model =  ExactGPRegressor(
    #     train_input[:train_points,:].to("cuda"), train_output[:train_points].to("cuda"), kernel,
    # ).to("cuda")

    if train:
        loss = model.fit(lr=1e-3, n_epochs=1500, verbose=1, random_state=0)
        #plt.plot(np.asarray(loss[0]))

        # Save model
        model_name = "fullAq_sgpr.pt"
        torch.save(model.state_dict(), os.path.join("models", model_name))
    if test:
        model_name = "Point_to_point_main_power.pt"
        model.load_state_dict(torch.load(os.path.join("./models", model_name)))
    return model

# %%
model = GP_model(train=True, test=False)
# Out:
# tensor(1.2396, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1, iter: 1, loss: 1.2396
# tensor(1.2384, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 2, iter: 1, loss: 1.2384
# tensor(1.2377, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 3, iter: 1, loss: 1.2377
# tensor(1.2371, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 4, iter: 1, loss: 1.2371
# tensor(1.2366, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 5, iter: 1, loss: 1.2366
# tensor(1.2363, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 6, iter: 1, loss: 1.2363
# tensor(1.2360, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 7, iter: 1, loss: 1.2360
# tensor(1.2357, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 8, iter: 1, loss: 1.2357
# tensor(1.2354, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 9, iter: 1, loss: 1.2354
# tensor(1.2351, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 10, iter: 1, loss: 1.2351
# tensor(1.2349, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 11, iter: 1, loss: 1.2349
# tensor(1.2347, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 12, iter: 1, loss: 1.2347
# tensor(1.2346, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 13, iter: 1, loss: 1.2346
# tensor(1.2344, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 14, iter: 1, loss: 1.2344
# tensor(1.2343, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 15, iter: 1, loss: 1.2343
# /home/desai.aadesh/miniconda3/envs/nlim/lib/python3.10/site-packages/gpytorch/kernels/inducing_point_kernel.py:61: UserWarning: torch.triangular_solve is deprecated in favor of torch.linalg.solve_triangularand will be removed in a future PyTorch release.
# torch.linalg.solve_triangular has its arguments reversed and does not return a copy of one of the inputs.
# X = torch.triangular_solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve_triangular(A, B). (Triggered internally at  /opt/conda/conda-bld/pytorch_1656352645774/work/aten/src/ATen/native/BatchLinearAlgebra.cpp:2183.)
#   inv_root = torch.triangular_solve(eye, chol)[0]
# tensor(1.2342, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 16, iter: 1, loss: 1.2342
# tensor(1.2341, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 17, iter: 1, loss: 1.2341
# tensor(1.2340, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 18, iter: 1, loss: 1.2340
# tensor(1.2338, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 19, iter: 1, loss: 1.2338
# tensor(1.2337, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 20, iter: 1, loss: 1.2337
# tensor(1.2336, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 21, iter: 1, loss: 1.2336
# tensor(1.2335, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 22, iter: 1, loss: 1.2335
# tensor(1.2334, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 23, iter: 1, loss: 1.2334
# tensor(1.2333, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 24, iter: 1, loss: 1.2333
# tensor(1.2332, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 25, iter: 1, loss: 1.2332
# tensor(1.2331, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 26, iter: 1, loss: 1.2331
# tensor(1.2330, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 27, iter: 1, loss: 1.2330
# tensor(1.2330, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 28, iter: 1, loss: 1.2330
# tensor(1.2329, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 29, iter: 1, loss: 1.2329
# tensor(1.2329, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 30, iter: 1, loss: 1.2329
# tensor(1.2328, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 31, iter: 1, loss: 1.2328
# tensor(1.2327, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 32, iter: 1, loss: 1.2327
# tensor(1.2327, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 33, iter: 1, loss: 1.2327
# tensor(1.2326, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 34, iter: 1, loss: 1.2326
# tensor(1.2326, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 35, iter: 1, loss: 1.2326
# tensor(1.2325, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 36, iter: 1, loss: 1.2325
# tensor(1.2325, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 37, iter: 1, loss: 1.2325
# tensor(1.2324, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 38, iter: 1, loss: 1.2324
# tensor(1.2323, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 39, iter: 1, loss: 1.2323
# tensor(1.2323, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 40, iter: 1, loss: 1.2323
# tensor(1.2322, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 41, iter: 1, loss: 1.2322
# tensor(1.2322, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 42, iter: 1, loss: 1.2322
# tensor(1.2321, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 43, iter: 1, loss: 1.2321
# tensor(1.2321, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 44, iter: 1, loss: 1.2321
# tensor(1.2320, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 45, iter: 1, loss: 1.2320
# tensor(1.2320, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 46, iter: 1, loss: 1.2320
# tensor(1.2319, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 47, iter: 1, loss: 1.2319
# tensor(1.2319, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 48, iter: 1, loss: 1.2319
# tensor(1.2318, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 49, iter: 1, loss: 1.2318
# tensor(1.2318, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 50, iter: 1, loss: 1.2318
# tensor(1.2317, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 51, iter: 1, loss: 1.2317
# tensor(1.2317, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 52, iter: 1, loss: 1.2317
# tensor(1.2317, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 53, iter: 1, loss: 1.2317
# tensor(1.2316, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 54, iter: 1, loss: 1.2316
# tensor(1.2316, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 55, iter: 1, loss: 1.2316
# tensor(1.2315, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 56, iter: 1, loss: 1.2315
# tensor(1.2315, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 57, iter: 1, loss: 1.2315
# tensor(1.2314, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 58, iter: 1, loss: 1.2314
# tensor(1.2314, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 59, iter: 1, loss: 1.2314
# tensor(1.2314, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 60, iter: 1, loss: 1.2314
# tensor(1.2313, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 61, iter: 1, loss: 1.2313
# tensor(1.2313, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 62, iter: 1, loss: 1.2313
# tensor(1.2312, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 63, iter: 1, loss: 1.2312
# tensor(1.2312, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 64, iter: 1, loss: 1.2312
# tensor(1.2311, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 65, iter: 1, loss: 1.2311
# tensor(1.2311, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 66, iter: 1, loss: 1.2311
# tensor(1.2311, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 67, iter: 1, loss: 1.2311
# tensor(1.2310, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 68, iter: 1, loss: 1.2310
# tensor(1.2310, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 69, iter: 1, loss: 1.2310
# tensor(1.2309, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 70, iter: 1, loss: 1.2309
# tensor(1.2309, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 71, iter: 1, loss: 1.2309
# tensor(1.2309, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 72, iter: 1, loss: 1.2309
# tensor(1.2308, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 73, iter: 1, loss: 1.2308
# tensor(1.2308, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 74, iter: 1, loss: 1.2308
# tensor(1.2307, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 75, iter: 1, loss: 1.2307
# tensor(1.2307, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 76, iter: 1, loss: 1.2307
# tensor(1.2307, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 77, iter: 1, loss: 1.2307
# tensor(1.2306, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 78, iter: 1, loss: 1.2306
# tensor(1.2306, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 79, iter: 1, loss: 1.2306
# tensor(1.2305, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 80, iter: 1, loss: 1.2305
# tensor(1.2305, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 81, iter: 1, loss: 1.2305
# tensor(1.2305, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 82, iter: 1, loss: 1.2305
# tensor(1.2304, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 83, iter: 1, loss: 1.2304
# tensor(1.2304, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 84, iter: 1, loss: 1.2304
# tensor(1.2303, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 85, iter: 1, loss: 1.2303
# tensor(1.2303, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 86, iter: 1, loss: 1.2303
# tensor(1.2303, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch:
device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 191, iter: 1, loss: 1.2266
# tensor(1.2266, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 192, iter: 1, loss: 1.2266
# tensor(1.2265, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 193, iter: 1, loss: 1.2265
# tensor(1.2265, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 194, iter: 1, loss: 1.2265
# tensor(1.2265, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 195, iter: 1, loss: 1.2265
# tensor(1.2264, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 196, iter: 1, loss: 1.2264
# tensor(1.2264, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 197, iter: 1, loss: 1.2264
# tensor(1.2264, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 198, iter: 1, loss: 1.2264
# tensor(1.2264, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 199, iter: 1, loss: 1.2264
# tensor(1.2263, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 200, iter: 1, loss: 1.2263
# tensor(1.2263, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 201, iter: 1, loss: 1.2263
# tensor(1.2263, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 202, iter: 1, loss: 1.2263
# tensor(1.2262, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 203, iter: 1, loss: 1.2262
# tensor(1.2262, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 204, iter: 1, loss: 1.2262
# tensor(1.2262, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 205, iter: 1, loss: 1.2262
# tensor(1.2261, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 206, iter: 1, loss: 1.2261
# tensor(1.2261, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 207, iter: 1, loss: 1.2261
# tensor(1.2261, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 208, iter: 1, loss: 1.2261
# tensor(1.2261, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 209, iter: 1, loss: 1.2261
# tensor(1.2260, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 210, iter: 1, loss: 1.2260
# tensor(1.2260, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 211, iter: 1, loss: 1.2260
# tensor(1.2260, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 212, iter: 1, loss: 1.2260
# tensor(1.2259, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 213, iter: 1, loss: 1.2259
# tensor(1.2259, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 214, iter: 1, loss: 1.2259
# tensor(1.2259, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 215, iter: 1, loss: 1.2259
# tensor(1.2259, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 216, iter: 1, loss: 1.2259
# tensor(1.2258, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 217, iter: 1, loss: 1.2258
# tensor(1.2258, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 218, iter: 1, loss: 1.2258
# tensor(1.2258, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 219, iter: 1, loss: 1.2258
# tensor(1.2257, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 220, iter: 1, loss: 1.2257
# tensor(1.2257, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 221, iter: 1, loss: 1.2257
# tensor(1.2257, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 222, iter: 1, loss: 1.2257
# tensor(1.2257, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 223, iter: 1, loss: 1.2257
# tensor(1.2256, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 224, iter: 1, loss: 1.2256
# tensor(1.2256, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 225, iter: 1, loss: 1.2256
# tensor(1.2256, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 226, iter: 1, loss: 1.2256
# tensor(1.2255, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 227, iter: 1, loss: 1.2255
# tensor(1.2255, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 228, iter: 1, loss: 1.2255
# tensor(1.2255, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 229, iter: 1, loss: 1.2255
# tensor(1.2255, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 230, iter: 1, loss: 1.2255
# tensor(1.2254, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 231, iter: 1, loss: 1.2254
# tensor(1.2254, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 232, iter: 1, loss: 1.2254
# tensor(1.2254, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 233, iter: 1, loss: 1.2254
# tensor(1.2254, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 234, iter: 1, loss: 1.2254
# tensor(1.2253, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 235, iter: 1, loss: 1.2253
# tensor(1.2253, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 236, iter: 1, loss: 1.2253
# tensor(1.2253, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 237, iter: 1, loss: 1.2253
# tensor(1.2252, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 238, iter: 1, loss: 1.2252
# tensor(1.2252, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 239, iter: 1, loss: 1.2252
# tensor(1.2252, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 240, iter: 1, loss: 1.2252
# tensor(1.2252, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 241, iter: 1, loss: 1.2252
# tensor(1.2251, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 242, iter: 1, loss: 1.2251
# tensor(1.2251, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch:
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1371, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1372, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1373, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1374, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1375, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1376, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1377, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1378, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1379, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1380, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1381, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1382, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1383, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1384, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1385, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1386, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1387, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1388, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1389, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1390, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1391, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1392, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1393, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1394, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1395, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1396, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1397, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1398, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1399, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1400, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1401, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1402, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1403, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1404, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1405, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1406, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1407, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1408, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1409, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1410, iter: 1, loss: 1.2167
# tensor(1.2167, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1411, iter: 1, loss: 1.2167
# tensor(1.2166, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1412, iter: 1, loss: 1.2166
# tensor(1.2166, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1413, iter: 1, loss: 1.2166
# tensor(1.2166, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1414, iter: 1, loss: 1.2166
# tensor(1.2166, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1415, iter: 1, loss: 1.2166
# tensor(1.2166, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1416, iter: 1, loss: 1.2166
# tensor(1.2166, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1417, iter: 1, loss: 1.2166
# tensor(1.2166, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1418, iter: 1, loss: 1.2166
# tensor(1.2166, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1419, iter: 1, loss: 1.2166
# tensor(1.2166, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1420, iter: 1, loss: 1.2166
# tensor(1.2166, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1421, iter: 1, loss: 1.2166
# tensor(1.2166, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1422, iter: 1, loss: 1.2166
# tensor(1.2166, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1423, iter: 1, loss: 1.2166
# tensor(1.2166, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1424, iter: 1, loss: 1.2166
# tensor(1.2166, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1425, iter: 1, loss: 1.2166
# tensor(1.2166, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1426, iter: 1, loss: 1.2166
# tensor(1.2166, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1427, iter: 1, loss: 1.2166
# tensor(1.2166, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1428, iter: 1, loss: 1.2166
# tensor(1.2166, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1429, iter: 1, loss: 1.2166
# tensor(1.2166, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1430, iter: 1, loss: 1.2166
# tensor(1.2166, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1431, iter: 1, loss: 1.2166
# tensor(1.2166, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1432, iter: 1, loss: 1.2166
# tensor(1.2166, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1433, iter: 1, loss: 1.2166
# tensor(1.2166, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1434, iter: 1, loss: 1.2166
# tensor(1.2166, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1435, iter: 1, loss: 1.2166
# tensor(1.2166, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1436, iter: 1, loss: 1.2166
# tensor(1.2166, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1437, iter: 1, loss: 1.2166
# tensor(1.2166, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1438, iter: 1, loss: 1.2166
# tensor(1.2166, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1439, iter: 1, loss: 1.2166
# tensor(1.2166, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1440, iter: 1, loss: 1.2166
# tensor(1.2166, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1441, iter: 1, loss: 1.2166
# tensor(1.2166, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1442, iter: 1, loss: 1.2166
# tensor(1.2166, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1443, iter: 1, loss: 1.2166
# tensor(1.2166, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1444, iter: 1, loss: 1.2166
# tensor(1.2166, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1445, iter: 1, loss: 1.2166
# tensor(1.2166, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1446, iter: 1, loss: 1.2166
# tensor(1.2166, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1447, iter: 1, loss: 1.2166
# tensor(1.2165, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1448, iter: 1, loss: 1.2165
# tensor(1.2165, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1449, iter: 1, loss: 1.2165
# tensor(1.2165, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1450, iter: 1, loss: 1.2165
# tensor(1.2165, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1451, iter: 1, loss: 1.2165
# tensor(1.2165, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1452, iter: 1, loss: 1.2165
# tensor(1.2165, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1453, iter: 1, loss: 1.2165
# tensor(1.2165, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1454, iter: 1, loss: 1.2165
# tensor(1.2165, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1455, iter: 1, loss: 1.2165
# tensor(1.2165, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1456, iter: 1, loss: 1.2165
# tensor(1.2165, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1457, iter: 1, loss: 1.2165
# tensor(1.2165, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1458, iter: 1, loss: 1.2165
# tensor(1.2165, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1459, iter: 1, loss: 1.2165
# tensor(1.2165, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1460, iter: 1, loss: 1.2165
# tensor(1.2165, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1461, iter: 1, loss: 1.2165
# tensor(1.2165, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1462, iter: 1, loss: 1.2165
# tensor(1.2165, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1463, iter: 1, loss: 1.2165
# tensor(1.2165, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1464, iter: 1, loss: 1.2165
# tensor(1.2165, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1465, iter: 1, loss: 1.2165
# tensor(1.2165, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1466, iter: 1, loss: 1.2165
# tensor(1.2165, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1467, iter: 1, loss: 1.2165
# tensor(1.2165, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1468, iter: 1, loss: 1.2165
# tensor(1.2165, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1469, iter: 1, loss: 1.2165
# tensor(1.2165, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1470, iter: 1, loss: 1.2165
# tensor(1.2165, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1471, iter: 1, loss: 1.2165
# tensor(1.2165, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1472, iter: 1, loss: 1.2165
# tensor(1.2165, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1473, iter: 1, loss: 1.2165
# tensor(1.2165, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1474, iter: 1, loss: 1.2165
# tensor(1.2165, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1475, iter: 1, loss: 1.2165
# tensor(1.2165, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1476, iter: 1, loss: 1.2165
# tensor(1.2165, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1477, iter: 1, loss: 1.2165
# tensor(1.2165, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1478, iter: 1, loss: 1.2165
# tensor(1.2165, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1479, iter: 1, loss: 1.2165
# tensor(1.2165, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1480, iter: 1, loss: 1.2165
# tensor(1.2165, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1481, iter: 1, loss: 1.2165
# tensor(1.2165, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1482, iter: 1, loss: 1.2165
# tensor(1.2165, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1483, iter: 1, loss: 1.2165
# tensor(1.2164, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1484, iter: 1, loss: 1.2164
# tensor(1.2164, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1485, iter: 1, loss: 1.2164
# tensor(1.2164, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1486, iter: 1, loss: 1.2164
# tensor(1.2164, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1487, iter: 1, loss: 1.2164
# tensor(1.2164, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1488, iter: 1, loss: 1.2164
# tensor(1.2164, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1489, iter: 1, loss: 1.2164
# tensor(1.2164, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1490, iter: 1, loss: 1.2164
# tensor(1.2164, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1491, iter: 1, loss: 1.2164
# tensor(1.2164, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1492, iter: 1, loss: 1.2164
# tensor(1.2164, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1493, iter: 1, loss: 1.2164
# tensor(1.2164, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1494, iter: 1, loss: 1.2164
# tensor(1.2164, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1495, iter: 1, loss: 1.2164
# tensor(1.2164, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1496, iter: 1, loss: 1.2164
# tensor(1.2164, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1497, iter: 1, loss: 1.2164
# tensor(1.2164, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1498, iter: 1, loss: 1.2164
# tensor(1.2164, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1499, iter: 1, loss: 1.2164
# tensor(1.2164, device='cuda:0', grad_fn=<NegBackward0>)
# restart: 0, epoch: 1500, iter: 1, loss: 1.2164

# %%
pred_dist = model.predict((test_input[:10000,:]).to("cuda"))
y_mean = pred_dist.loc
y_mean = scaler_pm.inverse_transform(y_mean.reshape(-1, 1).cpu()).squeeze()

print(test_output.shape, y_mean.shape)
y_mean = np.clip(y_mean, 0, y_mean.max(), out=y_mean)
var_pred = pred_dist.variance
var_pred = scaler_pm.inverse_transform(var_pred.reshape(-1, 1).detach().cpu()).squeeze()
std_pred = pred_dist.stddev
# std_pred = torch.tensor(
#     scaler_y.inverse_transform(std_pred.reshape(-1, 1).detach().cpu()).squeeze()
# )
# Out:
# torch.Size([87600]) (10000,)

# %%
std_pred
# Out:
# tensor([0.8130, 0.8131, 0.8130,  ..., 0.8144, 0.8152, 0.8148], device='cuda:0',
#        grad_fn=<SqrtBackward0>)

# %%
print('Test MAE: {}'.format(torch.mean(torch.abs(torch.tensor(y_mean) - test_output[:10000]))))
# Out:
# Test MAE: 42.9829982688531

# %%
std_pred = np.array(std_pred.detach().cpu())/scaler_pm.var_

# %%
scaler_pm.mean_, scaler_pm.var_
# Out:
# (array([80.3643778]), array([6252.23943453]))

# %%
preds_stds = np.array(std_pred)
preds_mean = np.array(y_mean)
lower_line = preds_mean - 2 * preds_stds
upper_line = preds_mean + 2 * preds_stds

test_points = 10000

test_y1 = np.array(test_output)
print(preds_mean.shape, preds_stds.shape)

plt.rcParams["figure.dpi"] = 150
fig = plt.figure(figsize=(18, 8))
plt.fill_between(
    range(len(test_y1[:test_points])),
    lower_line[:],
    upper_line[:],
    facecolor="gray",
    alpha=0.5,
    label=r"95% confidence",
)
print(0)
plt.plot(preds_mean[:], label=r"predicted", linewidth=1.5)
# y_test = test_y1[:5000,:]
plt.plot(test_y1[:test_points], label=r"actual", linewidth=1.5)
plt.ylabel("PM2.5")
plt.legend()
plt.xlabel("10000 test points")
plt.title(
    "MOGP"
)
# plt.savefig(f"deep_variational_station_1006_{i}.png")
# model.train()

# %
# Out:
# (10000,) (10000,)
# 0
# Text(0.5, 1.0, 'MOGP')

# %%
# from gpytorch.means import ConstantMean
# from gpytorch.kernels import ScaleKernel, RBFKernel, InducingPointKernel
# from gpytorch.distributions import MultivariateNormal

# class GPRegressionModel(gpytorch.models.ExactGP):
#     def __init__(self, train_x, train_y, likelihood):
#         super(GPRegressionModel, self).__init__(train_x, train_y, likelihood)
#         self.mean_module = ConstantMean()
#         self.base_covar_module = ScaleKernel(RBFKernel())
#         self.covar_module = InducingPointKernel(self.base_covar_module, inducing_points=train_x[:50, :].to("cuda:0"), likelihood=likelihood)

#     def forward(self, x):
#         mean_x = self.mean_module(x)
#         covar_x = self.covar_module(x)
#         return MultivariateNormal(mean_x, covar_x)

# %%
# likelihood = gpytorch.likelihoods.GaussianLikelihood().to("cuda:0")
# model = GPRegressionModel(train_x[:20000,:].to("cuda:0"), train_y[:20000].to("cuda:0"), likelihood).to("cuda:0")

# %%
# training_iterations = 300

# # Find optimal model hyperparameters
# model.train()
# likelihood.train()

# # Use the adam optimizer
# optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# # "Loss" for GPs - the marginal log likelihood
# mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)

# def train():
#     for i in range(training_iterations):
#         # Zero backprop gradients
#         optimizer.zero_grad()
#         # Get output from model
#         output = model(train_x[:20000,:].to("cuda:0"))
#         # Calc loss and backprop derivatives
#         loss = -mll(output, train_y[:20000].to("cuda:0"))
#         loss.backward()
#         print('Iter %d/%d - Loss: %.3f' % (i + 1, training_iterations, loss.item()))
#         optimizer.step()
#         torch.cuda.empty_cache()

# # See dkl_mnist.ipynb for explanation of this flag
# %time train()

# %%
# model.eval()
# likelihood.eval()
# with gpytorch.settings.max_preconditioner_size(10), torch.no_grad():
#     preds = model(test_input[:10000,:].to("cuda:0"))

# %%
# print('Test MAE: {}'.format(torch.mean(torch.abs(scaler_y.inverse_transform(preds.mean.cpu()) - test_output[:10000,0]))))

# %% [markdown]
# ## RF

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
train_points = 20000

modelRF = RandomForestRegressor(n_estimators=100, max_depth=30, random_state=0)
modelRF.fit(train_input[:train_points,:], train_output[:train_points])
# Out:
# RandomForestRegressor(max_depth=30, random_state=0)

# %%
pred_rf = modelRF.predict(test_input[:10000,:])

# %%
print('Test MAE: {}'.format(torch.mean(torch.abs(torch.tensor(scaler_pm.inverse_transform(pred_rf.reshape(-1,1))) - test_output[:10000]))))
# Out:
# Test MAE: 66.65256311480749

# %%
# preds_stds = np.array(std_pred)
# preds_mean = np.array(y_mean)
# lower_line = preds_mean - 2 * preds_stds
# upper_line = preds_mean + 2 * preds_stds

test_points = 10000

test_y1 = np.array(test_output)
# print(preds_mean.shape, preds_stds.shape)

plt.rcParams["figure.dpi"] = 150
fig = plt.figure(figsize=(18, 8))
# plt.fill_between(
#     range(len(test_y1[:test_points])),
#     lower_line[:],
#     upper_line[:],
#     facecolor="gray",
#     alpha=0.5,
#     label=r"95% confidence",
# )
print(0)
plt.plot(scaler_pm.inverse_transform(pred_rf.reshape(-1,1)), label=r"predicted", linewidth=1.5)
# y_test = test_y1[:5000,:]
plt.plot(test_y1[:test_points], label=r"actual", linewidth=1.5)
plt.ylabel("PM2.5")
plt.legend()
plt.xlabel("10000 test points")
plt.title(
    "RF"
)
# Out:
# 0
# Text(0.5, 1.0, 'RF')

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsRegressor
neigh = KNeighborsRegressor()
neigh.fit(train_input[:train_points,:], train_output[:train_points])
# Out:
# KNeighborsRegressor()

# %%
pred_knn = neigh.predict(test_input[:10000,:])

# %%
print('Test MAE: {}'.format(torch.mean(torch.abs(torch.tensor(scaler_pm.inverse_transform(pred_knn.reshape(-1,1))) - test_output[:10000]))))
# Out:
# Test MAE: 63.16094970703125

# %%
# preds_stds = np.array(std_pred)
# preds_mean = np.array(y_mean)
# lower_line = preds_mean - 2 * preds_stds
# upper_line = preds_mean + 2 * preds_stds

test_points = 10000

test_y1 = np.array(test_output)
# print(preds_mean.shape, preds_stds.shape)

plt.rcParams["figure.dpi"] = 150
fig = plt.figure(figsize=(18, 8))
# plt.fill_between(
#     range(len(test_y1[:test_points])),
#     lower_line[:],
#     upper_line[:],
#     facecolor="gray",
#     alpha=0.5,
#     label=r"95% confidence",
# )
print(0)
plt.plot(scaler_pm.inverse_transform(pred_knn.reshape(-1,1)), label=r"predicted", linewidth=1.5)
# y_test = test_y1[:5000,:]
plt.plot(test_y1[:test_points], label=r"actual", linewidth=1.5)
plt.ylabel("PM2.5")
plt.legend()
plt.xlabel("10000 test points")
plt.title(
    "KNN"
)
# Out:
# 0
# Text(0.5, 1.0, 'KNN')

# %% [markdown]
# ## linear_reg

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression().fit(train_input[:train_points,:], train_output[:train_points])

# %%
pred_lr = reg.predict(test_input[:10000,:])

# %%
print('Test MAE: {}'.format(torch.mean(torch.abs(torch.tensor(scaler_pm.inverse_transform(pred_lr.reshape(-1,1))) - test_output[:10000]))))
# Out:
# Test MAE: 56.91831970214844

# %%
# preds_stds = np.array(std_pred)
# preds_mean = np.array(y_mean)
# lower_line = preds_mean - 2 * preds_stds
# upper_line = preds_mean + 2 * preds_stds

test_points = 10000

test_y1 = np.array(test_output)
# print(preds_mean.shape, preds_stds.shape)

plt.rcParams["figure.dpi"] = 150
fig = plt.figure(figsize=(18, 8))
# plt.fill_between(
#     range(len(test_y1[:test_points])),
#     lower_line[:],
#     upper_line[:],
#     facecolor="gray",
#     alpha=0.5,
#     label=r"95% confidence",
# )
print(0)
plt.plot(scaler_pm.inverse_transform(pred_lr.reshape(-1,1)), label=r"predicted", linewidth=1.5)
# y_test = test_y1[:5000,:]
plt.plot(test_y1[:test_points], label=r"actual", linewidth=1.5)
plt.ylabel("PM2.5")
plt.legend()
plt.xlabel("10000 test points")
plt.title(
    "lr"
)
# Out:
# 0
# Text(0.5, 1.0, 'lr')
